# %%
from geopy.distance import geodesic
import numpy as np

import os
import sys
import random
import argparse
import time
import pandas as pd

import mygraph
import main
from language_model import Skipgram

from collections import Counter
from gensim.models import Word2Vec, KeyedVectors
from gensim.models.word2vec import Vocab
from multiprocessing import cpu_count
import networkx as nx
import numpy as np
import scipy.sparse as sp

import logging
from gensim.models.callbacks import CallbackAny2Vec

# %%
#embedding generation
model = Skipgram.load("skipgram_model")

embedding_results = {}
for i in range(G.num_of_nodes):
    embedding_results[i] = list(model.wv[str(i)])
    #embedding_results.append(model.wv[str(i)])

embedding_dim = len(embedding_results[0])

# convert n-dimensional embedding to 2-dim(to satisfy Theorem 1.)
df = pd.DataFrame(columns = range(0,embedding_dim))

for i in range(G.num_of_nodes):
    df.loc[i] = embedding_results[float(i)]

#print(df)

#Implement PCA to reduce dimensionality of embeddings

#vector representation(embeddings) list
X = df.values.tolist()
#print(X)
#Computing correlation of matrix
X_corr=df.corr()

#Computing eigen values and eigen vectors
values,vectors=np.linalg.eig(X_corr)

#Sorting the eigen vectors coresponding to eigen values in descending order
arg = (-values).argsort()
values = vectors[arg]
vectors = vectors[:, arg]

#Taking first 2 components which explain maximum variance for projecting
new_vectors=vectors[:,:2]

#Projecting it onto new dimesion with 2 axis
neww_X=np.dot(X,new_vectors)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/Desktop/danbi_study/MY_Deepwalk/myenv/lib/python3.8/site-packages/gensim/models/word2vec.py in load(cls, *args, **kwargs)
#    1140         try:
# -> 1141             model = super(Word2Vec, cls).load(*args, **kwargs)
#    1142
#
# ~/Desktop/danbi_study/MY_Deepwalk/myenv/lib/python3.8/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#    1229         """
# -> 1230         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
#    1231         if not hasattr(model, 'ns_exponent'):
#
# ~/Desktop/danbi_study/MY_Deepwalk/myenv/lib/python3.8/site-packages/gensim/models/base_any2vec.py in load(cls, fname_or_handle, **kwargs)
#     601         """
# --> 602         return super(BaseAny2VecModel, cls).load(fname_or_handle, **kwargs)
#     603
#
# ...

# %%
#randomwalk based curvature regularization
#generate random walks for entire nodes

#2-dim에만 해당되는 것인지(o) resolved!!!!

def abs_curvature_regularization(walks, embedding_result, num_walks):
       
    #get tangent of each node(vector)
    #each node has 10 numbers of random walks(total 34 x 10 walks)
    
    
    for i in len(walks):#iter 340(340 number of random_walks: 10 for each 34 nodes)
        embedding_of_randwalk = []
        #for each random_walk(current random_walk)
        cur_walk = walks[i]
        #calculate ABS curvature of node q in i random_walk 
        for q in len(cur_walk):
            #get 2-dim embedding of node q
            embedding_of_randwalk.append(embedding_result[q])
        
        
    
    
#remove any cycle in random walks(undirecetd graph is acyclic) resolved!!!!


#optimization


#compute angle-based sectional curvature for each vertex in random walk(from n_i to n_j)


#apply cosine function to each computed angle
